# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkurMali/IST597_Spring_2022/blob/main/MLP_Fmnist_Saver_optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import time
import tensorflow as tf
from tensorflow import keras
print(tf.version.VERSION)
import matplotlib.pyplot as plt


np.random.seed(1234)
tf.random.set_seed(1234)
# Out:
# 2.8.0

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data() # Load MNIST or FMNIST
assert X_train.shape == (60000, 28, 28)
assert X_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)


# Display randomly selected data
indices = list(np.random.randint(X_train.shape[0],size=3))
for i in range(3):
    plt.subplot(1,3,i+1)
    plt.imshow(X_train[indices[i]].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Index {} Class {}".format(indices[i], y_train[indices[i]]))
    plt.tight_layout()

# %% [markdown]
# # Important
# * Always have a validation set, the procedure to create validation or dev set is by performing random sample without replacement on train set and then only using that fraction as dev set.
# * Simple approach is to set some K samples, you can extract them from start, mid or end.
# * Imagine validation set that partially approximates test set distribution and we assume our model would produce identical results when we test it on test set.
# * Always optimize your hyperparameters by looking at performance on validation set and not test set.
# * Do not touch test set, we have this to test how our model would work on unseen data.

# %%
# Split train dataset into train and validation
X_val = X_train[50000:60000]
X_train = X_train[0:50000]
y_val = y_train[50000:60000]
y_train = y_train[0:50000]

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example is", str(X_train.shape[1]), "by", str(X_train.shape[2]))

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example is", str(X_val.shape[1]), "by", str(X_val.shape[2]))

X_train = X_train.reshape(50000, 28*28)
X_val = X_val.reshape(10000, 28*28)
X_test = X_test.reshape(10000, 28*28)

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example has", str(X_train.shape[1]), "features")

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example has", str(X_val.shape[1]), "features")

# Split dataset into batches
#train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(16)
#test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)
# Out:
# size of training set is 50000 samples
# every train example is 28 by 28
# size of validation set is 10000 samples
# every validation example is 28 by 28
# size of training set is 50000 samples
# every train example has 784 features
# size of validation set is 10000 samples
# every validation example has 784 features

# %% [markdown]
# # Points to remember
# * If using any type of neural network, normalize your input between 0-1.
# * One can use various procedures to achieve this, divide by largest value (for images we use 255), subtract mean from data and then normalize, one can even augment them and use other steps for normalization.
# * Normalization is important step, one could observe significant boost in performance just by having better normalization scheme.
# * For targets we always use one-hot encodings.

# %%
#Normalize Data

X_train = X_train/255
X_val = X_val/255
X_test = X_test/255
# X_train[0]
np.max(X_train)
# Out:
# 1.0

# %%
size_input = X_train.shape[1]
size_hidden1 = 128
size_hidden2 = 128
size_hidden3 = 128
size_output = 10

number_of_train_examples = X_train.shape[0]
number_of_test_examples = X_test.shape[0]

y_train = tf.keras.utils.to_categorical(y_train, num_classes=10) # Other function is tf.one_hot(y_train,depth=10)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
print(tf.shape(y_val))
# Out:
# tf.Tensor([10000    10], shape=(2,), dtype=int32)

# %% [markdown]
# # Importance of weight initialization
#
# * One reason backprop based models can perform bettter lies with the weight initialization method, one important point one should remember is that, if yur weights are initialized to be too high or low, backprop would struggle.
# * Hence one should always carefully initialize weights of your model, below i have shown approach with random_normal, one can use random_uniform, truncated version of both, Xavier init and orthogonal.
# * You will find modern day NNs have achieved stable and better performance by simply switching to better init and majority of cases Xavier or Orthogonal works best.
# * Always initialize your bias using zero or some small constant (ideally 0.01 or less works better). We use bias to shift the activation and in some cases it can stabalize learning, but having large bias can cause negative results.
#
# # Loss function
#
# * We will always cross-entropy loss for classification.
#
# * tf softmax,
# loss= tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf)), this function is simply saying that it will calculate softmax for you, simply provide logits to it.
#
# * In other output of your forward pass directly goes this function. Now this operator will calculate or apply softmax over prediction or logits and calculate cross-entropy between prediction and target. I am using reduce_mean since we apply this over batches.
# * Second is using keras
# Method 1 :- This function requires logits, hence same as above you will pass logits or output variable to this function. Now remember you need from_logits = True, for this to work.
# cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
# loss_x = cce(y_true_tf, y_pred_tf)
#
# * Method 2:- In this we will apply softmax to output function and then pass to CCE loss.
# So the approach is
# output = tf.nn.softmax(output)
# cce = tf.keras.losses.CategoricalCrossentropy(from_logits=False)
# loss_x = cce(y_true_tf, y_pred_tf)

# %%
# Define class to build mlp model
class MLP(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None,keep_prob=0.0,use_l1=False,use_l2=False,use_cusOP=False):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device, self.keep_prob,self.use_l1,self.use_l2,self.use_cusOP=\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device,keep_prob,use_l1,use_l2,use_cusOP
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]


    self.alpha, self.beta_1, self.beta_2, self.beta_3, self.epslion = 1e-4, 0.9, 0.999, 0.999987, 10e-8

    m_list=[]
    v_list=[]
    u_list=[]
    for var in self.variables:
      m_list.append(tf.Variable(tf.zeros_like(var)))
      v_list.append(tf.Variable(tf.zeros_like(var)))
      u_list.append(tf.Variable(tf.zeros_like(var)))
    self.m=m_list
    self.v=v_list
    self.u=u_list
    self.t=0
  
 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    l1=tf.keras.regularizers.L1(l1=2e-5)
    l2=tf.keras.regularizers.L2(l2=2e-5)
    L1=l1(self.W1) + l1(self.W2)+l1(self.W3)+l1(self.W4)
    L2=l2(self.W1) + l2(self.W2)+l2(self.W3)+l2(self.W4)

    if self.use_l1:
      loss_x=loss_x+L1
    if self.use_l2:
      loss_x=loss_x+L2
    return loss_x

 def backward(self, X_train, y_train, opti):
    """
    backward pass
    """
    optimizer = opti
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
        
    grads = tape.gradient(current_loss, self.variables)
    if self.use_cusOP:
      self.t+=1
      for i in range(len(grads)):
        m = self.beta_1*self.m[i]+ (1 - self.beta_1)*grads[i]
        self.m[i].assign(m)
        v = self.beta_2*self.v[i]+ (1 - self.beta_2)*(grads[i]**2)
        self.v[i].assign(v)
        u = self.beta_3*self.u[i]+ (1 - self.beta_3)*(grads[i]**3)
        self.u[i].assign(u)

        mt = tf.math.divide(m, 1 - self.beta_1**self.t)
        vt = tf.math.divide(v, 1 - self.beta_2**self.t)
        ut = tf.math.divide(u, 1 - self.beta_3**self.t)
        
        vtRoot= tf.pow(vt, 1.0/2.0)
        #data type error
        utRoot= tf.math.sign(ut)*(tf.abs(ut)**(1.0/3.0))

        denominator = vtRoot+ self.epslion*utRoot+ 10e-8
        LRfactor = tf.math.divide(mt, denominator)
        theta=self.variables[i]- self.alpha*LRfactor
        self.variables[i].assign(theta)
      #print(len(self.variables))
    else:
      optimizer.apply_gradients(zip(grads, self.variables))
           
 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    h1 = tf.nn.dropout(h1, self.keep_prob)

    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    h2 = tf.nn.dropout(h2, self.keep_prob)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)
    h3 = tf.nn.dropout(h3, self.keep_prob)


    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

#  def stderr(self,y_pred):
#     """
#      Calculate standard error
#      """
#     y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
#     std_dev = np.std(y_pred_tf) #Calculates standard deviation
#     std_err = std_dev/sqrt(len(y_pred_tf))
#     return std_err 


#  def var(self,y_pred):
#     """
#      Calculate variance 
#      """
#     y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
#     std_dev = np.std(y_pred_tf) #Calculates standard deviation
#     variance = (std_dev**2) # calculate variance
#     return variance

# %%
# Set number of epochs
NUM_EPOCHS = 10

# Initialize model using CPU

#opti = customizerOP()

totalTestAcc=[]
for i in range(10):
  tf.random.set_seed(i+100)
  #test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(128)
  mlp_on_cpu = MLP(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu',use_l1=True,use_l2=True,use_cusOP=True)

  time_start = time.time()
  #temp opti but actually didnt use since cse_cusOP is set up True
  opti = tf.keras.optimizers.SGD(learning_rate = 0.1)
  correct_test_prediction = tf.Variable(0, dtype=tf.float32)


  # Initialize
  test_loss_total = tf.Variable(0, dtype=tf.float32)
  for epoch in range(NUM_EPOCHS):
      
    loss_total = tf.zeros([1,1], dtype=tf.float32)
    lt = 0
      
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(1234)).batch(128)
    

    kz = 0
    accuracy_z = 0.0
    cur_train_acc = 0.0
    for inputs, outputs in train_ds:
      qw, tr = tf.shape(inputs)
      kz = kz + 1
      preds = mlp_on_cpu.forward(inputs) 
      loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
      lt = lt + mlp_on_cpu.loss(preds, outputs)
      mlp_on_cpu.backward(inputs, outputs, opti)

    preds = mlp_on_cpu.forward(X_train)
    # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
    preds = tf.nn.softmax(preds)
    correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
    accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_train_acc += accuracy_z.numpy()
    ds = cur_train_acc
    print('\nTrain Accuracy: {:.4f}'.format(ds))
    print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
    preds_val = mlp_on_cpu.forward(X_val)
    preds_val = tf.nn.softmax(preds_val)
    correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_val_acc = accuracy.numpy()

    print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
    
    plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

          
  time_taken = time.time() - time_start
  #test_loss_total = 0.0
  # Validate model
  #for inputs, outputs in test_ds:
  #  preds = mlp_on_cpu.forward(inputs)
  #  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
  #print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

  # Test model
  preds_test = mlp_on_cpu.forward(X_test)
  preds_test = tf.nn.softmax(preds_test)
  correct_test_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_test_prediction, "float"))
  cur_test_acc = accuracy.numpy()
  print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
  totalTestAcc.append(cur_test_acc)
# Out:
# Train Accuracy: 0.8024
# Number of Epoch = 1 - Average Cross Entropy:= 0.009724109497070312
#
# Validation Accuracy: 0.7937
#
# Train Accuracy: 0.8342
# Number of Epoch = 2 - Average Cross Entropy:= 0.005977067260742187
#
# Validation Accuracy: 0.8242
#
# Train Accuracy: 0.8466
# Number of Epoch = 3 - Average Cross Entropy:= 0.005425717163085937
#
# Validation Accuracy: 0.8370
#
# Train Accuracy: 0.8548
# Number of Epoch = 4 - Average Cross Entropy:= 0.0051292730712890625
#
# Validation Accuracy: 0.8443
#
# Train Accuracy: 0.8614
# Number of Epoch = 5 - Average Cross Entropy:= 0.00492376220703125
#
# Validation Accuracy: 0.8501
#
# Train Accuracy: 0.8666
# Number of Epoch = 6 - Average Cross Entropy:= 0.00476915283203125
#
# Validation Accuracy: 0.8547
#
# Train Accuracy: 0.8706
# Number of Epoch = 7 - Average Cross Entropy:= 0.00464177734375
#
# Validation Accuracy: 0.8582
#
# Train Accuracy: 0.8739
# Number of Epoch = 8 - Average Cross Entropy:= 0.004532733764648437
#
# Validation Accuracy: 0.8615
#
# Train Accuracy: 0.8772
# Number of Epoch = 9 - Average Cross Entropy:= 0.0044398974609375
#
# Validation Accuracy: 0.8632
#
# Train Accuracy: 0.8796
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043559619140625
#
# Validation Accuracy: 0.8663
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8014
# Number of Epoch = 1 - Average Cross Entropy:= 0.009397921142578125
#
# Validation Accuracy: 0.7938
#
# Train Accuracy: 0.8367
# Number of Epoch = 2 - Average Cross Entropy:= 0.0058994512939453125
#
# Validation Accuracy: 0.8297
#
# Train Accuracy: 0.8486
# Number of Epoch = 3 - Average Cross Entropy:= 0.005384943237304688
#
# Validation Accuracy: 0.8430
#
# Train Accuracy: 0.8561
# Number of Epoch = 4 - Average Cross Entropy:= 0.005118349914550781
#
# Validation Accuracy: 0.8487
#
# Train Accuracy: 0.8616
# Number of Epoch = 5 - Average Cross Entropy:= 0.004934892883300781
#
# Validation Accuracy: 0.8523
#
# Train Accuracy: 0.8658
# Number of Epoch = 6 - Average Cross Entropy:= 0.004788644714355469
#
# Validation Accuracy: 0.8567
#
# Train Accuracy: 0.8698
# Number of Epoch = 7 - Average Cross Entropy:= 0.0046703564453125
#
# Validation Accuracy: 0.8602
#
# Train Accuracy: 0.8729
# Number of Epoch = 8 - Average Cross Entropy:= 0.0045704684448242185
#
# Validation Accuracy: 0.8617
#
# Train Accuracy: 0.8761
# Number of Epoch = 9 - Average Cross Entropy:= 0.004479382629394531
#
# Validation Accuracy: 0.8640
#
# Train Accuracy: 0.8790
# Number of Epoch = 10 - Average Cross Entropy:= 0.004399622497558594
#
# Validation Accuracy: 0.8660
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8017
# Number of Epoch = 1 - Average Cross Entropy:= 0.00944272216796875
#
# Validation Accuracy: 0.7953
#
# Train Accuracy: 0.8366
# Number of Epoch = 2 - Average Cross Entropy:= 0.005890782470703125
#
# Validation Accuracy: 0.8263
#
# Train Accuracy: 0.8492
# Number of Epoch = 3 - Average Cross Entropy:= 0.005328898315429688
#
# Validation Accuracy: 0.8402
#
# Train Accuracy: 0.8582
# Number of Epoch = 4 - Average Cross Entropy:= 0.005041006164550782
#
# Validation Accuracy: 0.8488
#
# Train Accuracy: 0.8630
# Number of Epoch = 5 - Average Cross Entropy:= 0.004843263244628906
#
# Validation Accuracy: 0.8557
#
# Train Accuracy: 0.8675
# Number of Epoch = 6 - Average Cross Entropy:= 0.004695496520996094
#
# Validation Accuracy: 0.8581
#
# Train Accuracy: 0.8715
# Number of Epoch = 7 - Average Cross Entropy:= 0.004577489318847656
#
# Validation Accuracy: 0.8614
#
# Train Accuracy: 0.8751
# Number of Epoch = 8 - Average Cross Entropy:= 0.0044750732421875
#
# Validation Accuracy: 0.8645
#
# Train Accuracy: 0.8779
# Number of Epoch = 9 - Average Cross Entropy:= 0.0043855328369140625
#
# Validation Accuracy: 0.8675
#
# Train Accuracy: 0.8813
# Number of Epoch = 10 - Average Cross Entropy:= 0.004306406555175781
#
# Validation Accuracy: 0.8688
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8086
# Number of Epoch = 1 - Average Cross Entropy:= 0.00950567626953125
#
# Validation Accuracy: 0.8020
#
# Train Accuracy: 0.8378
# Number of Epoch = 2 - Average Cross Entropy:= 0.005918151245117188
#
# Validation Accuracy: 0.8277
#
# Train Accuracy: 0.8500
# Number of Epoch = 3 - Average Cross Entropy:= 0.005399981689453125
#
# Validation Accuracy: 0.8389
#
# Train Accuracy: 0.8577
# Number of Epoch = 4 - Average Cross Entropy:= 0.0051180221557617185
#
# Validation Accuracy: 0.8478
#
# Train Accuracy: 0.8635
# Number of Epoch = 5 - Average Cross Entropy:= 0.004921426086425781
#
# Validation Accuracy: 0.8521
#
# Train Accuracy: 0.8684
# Number of Epoch = 6 - Average Cross Entropy:= 0.004765700073242188
#
# Validation Accuracy: 0.8564
#
# Train Accuracy: 0.8729
# Number of Epoch = 7 - Average Cross Entropy:= 0.004638907470703125
#
# Validation Accuracy: 0.8595
#
# Train Accuracy: 0.8770
# Number of Epoch = 8 - Average Cross Entropy:= 0.004532785034179688
#
# Validation Accuracy: 0.8638
#
# Train Accuracy: 0.8797
# Number of Epoch = 9 - Average Cross Entropy:= 0.004437174072265625
#
# Validation Accuracy: 0.8662
#
# Train Accuracy: 0.8820
# Number of Epoch = 10 - Average Cross Entropy:= 0.00435626220703125
#
# Validation Accuracy: 0.8690
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8058
# Number of Epoch = 1 - Average Cross Entropy:= 0.009817416381835937
#
# Validation Accuracy: 0.7997
#
# Train Accuracy: 0.8352
# Number of Epoch = 2 - Average Cross Entropy:= 0.005920790405273438
#
# Validation Accuracy: 0.8268
#
# Train Accuracy: 0.8471
# Number of Epoch = 3 - Average Cross Entropy:= 0.00537415771484375
#
# Validation Accuracy: 0.8388
#
# Train Accuracy: 0.8549
# Number of Epoch = 4 - Average Cross Entropy:= 0.005093429870605469
#
# Validation Accuracy: 0.8466
#
# Train Accuracy: 0.8601
# Number of Epoch = 5 - Average Cross Entropy:= 0.004900576782226562
#
# Validation Accuracy: 0.8528
#
# Train Accuracy: 0.8655
# Number of Epoch = 6 - Average Cross Entropy:= 0.004750978393554687
#
# Validation Accuracy: 0.8572
#
# Train Accuracy: 0.8698
# Number of Epoch = 7 - Average Cross Entropy:= 0.00462893798828125
#
# Validation Accuracy: 0.8612
#
# Train Accuracy: 0.8735
# Number of Epoch = 8 - Average Cross Entropy:= 0.0045227835083007815
#
# Validation Accuracy: 0.8637
#
# Train Accuracy: 0.8767
# Number of Epoch = 9 - Average Cross Entropy:= 0.004433135986328125
#
# Validation Accuracy: 0.8672
#
# Train Accuracy: 0.8795
# Number of Epoch = 10 - Average Cross Entropy:= 0.004353617553710937
#
# Validation Accuracy: 0.8682
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8066
# Number of Epoch = 1 - Average Cross Entropy:= 0.009393168334960938
#
# Validation Accuracy: 0.7965
#
# Train Accuracy: 0.8373
# Number of Epoch = 2 - Average Cross Entropy:= 0.0058741162109375
#
# Validation Accuracy: 0.8248
#
# Train Accuracy: 0.8489
# Number of Epoch = 3 - Average Cross Entropy:= 0.005360658569335938
#
# Validation Accuracy: 0.8371
#
# Train Accuracy: 0.8575
# Number of Epoch = 4 - Average Cross Entropy:= 0.005081141052246094
#
# Validation Accuracy: 0.8449
#
# Train Accuracy: 0.8633
# Number of Epoch = 5 - Average Cross Entropy:= 0.004884557495117187
#
# Validation Accuracy: 0.8495
#
# Train Accuracy: 0.8682
# Number of Epoch = 6 - Average Cross Entropy:= 0.004735911560058594
#
# Validation Accuracy: 0.8545
#
# Train Accuracy: 0.8715
# Number of Epoch = 7 - Average Cross Entropy:= 0.0046127734375
#
# Validation Accuracy: 0.8566
#
# Train Accuracy: 0.8743
# Number of Epoch = 8 - Average Cross Entropy:= 0.0045086898803710935
#
# Validation Accuracy: 0.8608
#
# Train Accuracy: 0.8774
# Number of Epoch = 9 - Average Cross Entropy:= 0.004417981567382812
#
# Validation Accuracy: 0.8633
#
# Train Accuracy: 0.8798
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043370758056640625
#
# Validation Accuracy: 0.8651
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8047
# Number of Epoch = 1 - Average Cross Entropy:= 0.009247012329101563
#
# Validation Accuracy: 0.7989
#
# Train Accuracy: 0.8353
# Number of Epoch = 2 - Average Cross Entropy:= 0.005931738891601562
#
# Validation Accuracy: 0.8266
#
# Train Accuracy: 0.8491
# Number of Epoch = 3 - Average Cross Entropy:= 0.005382727661132813
#
# Validation Accuracy: 0.8398
#
# Train Accuracy: 0.8578
# Number of Epoch = 4 - Average Cross Entropy:= 0.005092095642089844
#
# Validation Accuracy: 0.8453
#
# Train Accuracy: 0.8635
# Number of Epoch = 5 - Average Cross Entropy:= 0.004893201293945312
#
# Validation Accuracy: 0.8537
#
# Train Accuracy: 0.8682
# Number of Epoch = 6 - Average Cross Entropy:= 0.004741826782226562
#
# Validation Accuracy: 0.8590
#
# Train Accuracy: 0.8722
# Number of Epoch = 7 - Average Cross Entropy:= 0.004623526306152344
#
# Validation Accuracy: 0.8619
#
# Train Accuracy: 0.8754
# Number of Epoch = 8 - Average Cross Entropy:= 0.004524568176269532
#
# Validation Accuracy: 0.8648
#
# Train Accuracy: 0.8786
# Number of Epoch = 9 - Average Cross Entropy:= 0.0044380780029296876
#
# Validation Accuracy: 0.8665
#
# Train Accuracy: 0.8818
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043615325927734375
#
# Validation Accuracy: 0.8694
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8101
# Number of Epoch = 1 - Average Cross Entropy:= 0.0091541943359375
#
# Validation Accuracy: 0.8046
#
# Train Accuracy: 0.8384
# Number of Epoch = 2 - Average Cross Entropy:= 0.0059081591796875
#
# Validation Accuracy: 0.8300
#
# Train Accuracy: 0.8520
# Number of Epoch = 3 - Average Cross Entropy:= 0.005404224853515625
#
# Validation Accuracy: 0.8404
#
# Train Accuracy: 0.8589
# Number of Epoch = 4 - Average Cross Entropy:= 0.005125454711914062
#
# Validation Accuracy: 0.8480
#
# Train Accuracy: 0.8647
# Number of Epoch = 5 - Average Cross Entropy:= 0.004936283569335937
#
# Validation Accuracy: 0.8530
#
# Train Accuracy: 0.8685
# Number of Epoch = 6 - Average Cross Entropy:= 0.004789189453125
#
# Validation Accuracy: 0.8579
#
# Train Accuracy: 0.8720
# Number of Epoch = 7 - Average Cross Entropy:= 0.004669325256347656
#
# Validation Accuracy: 0.8617
#
# Train Accuracy: 0.8753
# Number of Epoch = 8 - Average Cross Entropy:= 0.004563752746582031
#
# Validation Accuracy: 0.8653
#
# Train Accuracy: 0.8775
# Number of Epoch = 9 - Average Cross Entropy:= 0.004470662231445313
#
# Validation Accuracy: 0.8672
#
# Train Accuracy: 0.8803
# Number of Epoch = 10 - Average Cross Entropy:= 0.004388836669921875
#
# Validation Accuracy: 0.8702
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8017
# Number of Epoch = 1 - Average Cross Entropy:= 0.009531893310546874
#
# Validation Accuracy: 0.7947
#
# Train Accuracy: 0.8350
# Number of Epoch = 2 - Average Cross Entropy:= 0.005948007202148438
#
# Validation Accuracy: 0.8258
#
# Train Accuracy: 0.8483
# Number of Epoch = 3 - Average Cross Entropy:= 0.005405637817382812
#
# Validation Accuracy: 0.8407
#
# Train Accuracy: 0.8579
# Number of Epoch = 4 - Average Cross Entropy:= 0.005116646423339844
#
# Validation Accuracy: 0.8479
#
# Train Accuracy: 0.8637
# Number of Epoch = 5 - Average Cross Entropy:= 0.004918114318847656
#
# Validation Accuracy: 0.8527
#
# Train Accuracy: 0.8685
# Number of Epoch = 6 - Average Cross Entropy:= 0.004762798156738282
#
# Validation Accuracy: 0.8563
#
# Train Accuracy: 0.8724
# Number of Epoch = 7 - Average Cross Entropy:= 0.0046397329711914065
#
# Validation Accuracy: 0.8603
#
# Train Accuracy: 0.8758
# Number of Epoch = 8 - Average Cross Entropy:= 0.004534447326660156
#
# Validation Accuracy: 0.8629
#
# Train Accuracy: 0.8787
# Number of Epoch = 9 - Average Cross Entropy:= 0.004443816528320313
#
# Validation Accuracy: 0.8644
#
# Train Accuracy: 0.8818
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043646832275390625
#
# Validation Accuracy: 0.8665
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8064
# Number of Epoch = 1 - Average Cross Entropy:= 0.009510164184570312
#
# Validation Accuracy: 0.8019
#
# Train Accuracy: 0.8371
# Number of Epoch = 2 - Average Cross Entropy:= 0.0059334283447265625
#
# Validation Accuracy: 0.8300
#
# Train Accuracy: 0.8495
# Number of Epoch = 3 - Average Cross Entropy:= 0.00538010498046875
#
# Validation Accuracy: 0.8444
#
# Train Accuracy: 0.8566
# Number of Epoch = 4 - Average Cross Entropy:= 0.005096235046386718
#
# Validation Accuracy: 0.8505
#
# Train Accuracy: 0.8618
# Number of Epoch = 5 - Average Cross Entropy:= 0.004901602478027344
#
# Validation Accuracy: 0.8566
#
# Train Accuracy: 0.8661
# Number of Epoch = 6 - Average Cross Entropy:= 0.0047512890625
#
# Validation Accuracy: 0.8605
#
# Train Accuracy: 0.8700
# Number of Epoch = 7 - Average Cross Entropy:= 0.004631038208007813
#
# Validation Accuracy: 0.8629
#
# Train Accuracy: 0.8735
# Number of Epoch = 8 - Average Cross Entropy:= 0.004526192016601562
#
# Validation Accuracy: 0.8653
#
# Train Accuracy: 0.8764
# Number of Epoch = 9 - Average Cross Entropy:= 0.004433858947753906
#
# Validation Accuracy: 0.8673
#
# Train Accuracy: 0.8795
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043533544921875
#
# Validation Accuracy: 0.8686
#
# Test Accuracy: 0.86

# %%
a=[1,2,3]
b=[4,5,6]
c=next(zip(a,b))
c

class test(object):
  def __init__(self):
    self.variable=[1,2,3,4]
  def show(self):
    print(self.variable)
temp=test()

def test2(variable):
  variable=variable*2

test2(temp.variable)
temp.show()

# %%
totalTestAcc
# Out:
# [0.8595,
#  0.8572,
#  0.8616,
#  0.8578,
#  0.8597,
#  0.8624,
#  0.8587,
#  0.8589,
#  0.8605,
#  0.8609]

# %%
class customizerOP(object):
  def __init__(self, alpha=1e-3,beta1=0.9, beta2=0.999, beta3=0.999987, epslion=1e-8):
    self.alpha,self.beta_1, self.beta_2, self.beta_3, self.epslion =alpha,beta1, beta2, beta3, epslion
    self.m=[]
    self.v=[]
    self.u=[]
    self.t=0
  def apply_gradients(self,variables,grad):

    if self.t==0:
      for var in variables:
        self.m.append(tf.Variable(tf.zeros_like(var)))
        self.v.append(tf.Variable(tf.zeros_like(var)))
        self.u.append(tf.Variable(tf.zeros_like(var)))
      #self.m=tf.convert_to_tensor(self.m)
      #self.u=tf.convert_to_tensor(self.v)
      #self.u=tf.convert_to_tensor(self.u)
    #variables=tf.convert_to_tensor(variables)
    #grad=tf.convert_to_tensor(grad)


    self.t+=1
    new_var=[]
    for i in range(len(grad)):
      m = tf.math.add(tf.math.scalar_mul(self.beta_1, self.m[i]), tf.math.scalar_mul(1 - self.beta_1, grad[i]))
      self.m[i].assign(m)
      v = tf.math.add(tf.math.scalar_mul(self.beta_2, self.v[i]), tf.math.scalar_mul(1 - self.beta_2, tf.pow(grad[i],2.0)))
      self.v[i].assign(v)
      u = tf.math.add(tf.math.scalar_mul(self.beta_3, self.u[i]), tf.math.scalar_mul(1 - self.beta_3, tf.pow(grad[i],3.0)))
      self.u[i]=u

      mt = tf.math.divide(m, 1 - tf.pow(self.beta_1, self.t))
      vt = tf.math.divide(v, 1 - tf.pow(self.beta_2, self.t))
      ut = tf.math.divide(u, 1 - tf.pow(self.beta_3, self.t))
      
      vtRoot= tf.pow(vt, 1.0/2.0)
      utRoot= tf.math.multiply(tf.math.sign(ut), tf.math.pow(tf.abs(ut), 1.0/3.0))

      denominator = tf.math.add(tf.math.add(vtRoot, tf.math.scalar_mul(self.epslion, utRoot)), 1e-8)
      LRfactor = tf.math.divide(mt, denominator)
      new_var.append(variables[i]- tf.math.scalar_mul(self.alpha, LRfactor))

    return new_var

# %% [markdown]
# #Adam
# * Combine RMSprop with momentum
# * Default optimizer in many applications
# * In some scenarios leads to poor performance such as Continual learning, lifelong learning, metalearning

# %%
# Set number of epochs
NUM_EPOCHS = 10

# Initialize model using CPU

#opti = customizerOP()

totalTestAcc_adam=[]
for i in range(10):
  tf.random.set_seed(i+100)
  #test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(128)
  mlp_on_cpu = MLP(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu',use_l1=True,use_l2=True)

  time_start = time.time()
  opti = tf.keras.optimizers.Adam(learning_rate = 1e-4)
  correct_test_prediction = tf.Variable(0, dtype=tf.float32)


  # Initialize
  test_loss_total = tf.Variable(0, dtype=tf.float32)
  for epoch in range(NUM_EPOCHS):
      
    loss_total = tf.zeros([1,1], dtype=tf.float32)
    lt = 0
      
    train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(1234)).batch(128)
    

    kz = 0
    accuracy_z = 0.0
    cur_train_acc = 0.0
    for inputs, outputs in train_ds:
      qw, tr = tf.shape(inputs)
      kz = kz + 1
      preds = mlp_on_cpu.forward(inputs) 
      loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
      lt = lt + mlp_on_cpu.loss(preds, outputs)
      mlp_on_cpu.backward(inputs, outputs, opti)

    preds = mlp_on_cpu.forward(X_train)
    # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
    preds = tf.nn.softmax(preds)
    correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
    accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_train_acc += accuracy_z.numpy()
    ds = cur_train_acc
    print('\nTrain Accuracy: {:.4f}'.format(ds))
    print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
    preds_val = mlp_on_cpu.forward(X_val)
    preds_val = tf.nn.softmax(preds_val)
    correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    cur_val_acc = accuracy.numpy()

    print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
    
    plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

          
  time_taken = time.time() - time_start
  #test_loss_total = 0.0
  # Validate model
  #for inputs, outputs in test_ds:
  #  preds = mlp_on_cpu.forward(inputs)
  #  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
  #print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

  # Test model
  preds_test = mlp_on_cpu.forward(X_test)
  preds_test = tf.nn.softmax(preds_test)
  correct_test_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_test_prediction, "float"))
  cur_test_acc = accuracy.numpy()
  print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
  totalTestAcc_adam.append(cur_test_acc)
# Out:
# Train Accuracy: 0.8024
# Number of Epoch = 1 - Average Cross Entropy:= 0.009725863037109376
#
# Validation Accuracy: 0.7942
#
# Train Accuracy: 0.8346
# Number of Epoch = 2 - Average Cross Entropy:= 0.00597572998046875
#
# Validation Accuracy: 0.8247
#
# Train Accuracy: 0.8467
# Number of Epoch = 3 - Average Cross Entropy:= 0.005424342041015625
#
# Validation Accuracy: 0.8368
#
# Train Accuracy: 0.8546
# Number of Epoch = 4 - Average Cross Entropy:= 0.005129518432617187
#
# Validation Accuracy: 0.8447
#
# Train Accuracy: 0.8609
# Number of Epoch = 5 - Average Cross Entropy:= 0.004926689453125
#
# Validation Accuracy: 0.8501
#
# Train Accuracy: 0.8662
# Number of Epoch = 6 - Average Cross Entropy:= 0.004771515502929687
#
# Validation Accuracy: 0.8547
#
# Train Accuracy: 0.8704
# Number of Epoch = 7 - Average Cross Entropy:= 0.004643781127929687
#
# Validation Accuracy: 0.8591
#
# Train Accuracy: 0.8739
# Number of Epoch = 8 - Average Cross Entropy:= 0.004535421142578125
#
# Validation Accuracy: 0.8629
#
# Train Accuracy: 0.8765
# Number of Epoch = 9 - Average Cross Entropy:= 0.004442218017578125
#
# Validation Accuracy: 0.8637
#
# Train Accuracy: 0.8795
# Number of Epoch = 10 - Average Cross Entropy:= 0.004358397827148437
#
# Validation Accuracy: 0.8664
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8016
# Number of Epoch = 1 - Average Cross Entropy:= 0.009397587890625
#
# Validation Accuracy: 0.7938
#
# Train Accuracy: 0.8364
# Number of Epoch = 2 - Average Cross Entropy:= 0.005901119384765625
#
# Validation Accuracy: 0.8296
#
# Train Accuracy: 0.8491
# Number of Epoch = 3 - Average Cross Entropy:= 0.005385541381835938
#
# Validation Accuracy: 0.8444
#
# Train Accuracy: 0.8566
# Number of Epoch = 4 - Average Cross Entropy:= 0.005117669677734375
#
# Validation Accuracy: 0.8500
#
# Train Accuracy: 0.8614
# Number of Epoch = 5 - Average Cross Entropy:= 0.00493389892578125
#
# Validation Accuracy: 0.8530
#
# Train Accuracy: 0.8654
# Number of Epoch = 6 - Average Cross Entropy:= 0.004788743896484375
#
# Validation Accuracy: 0.8572
#
# Train Accuracy: 0.8695
# Number of Epoch = 7 - Average Cross Entropy:= 0.004671343078613281
#
# Validation Accuracy: 0.8587
#
# Train Accuracy: 0.8727
# Number of Epoch = 8 - Average Cross Entropy:= 0.004573201599121094
#
# Validation Accuracy: 0.8619
#
# Train Accuracy: 0.8756
# Number of Epoch = 9 - Average Cross Entropy:= 0.0044825732421875
#
# Validation Accuracy: 0.8644
#
# Train Accuracy: 0.8786
# Number of Epoch = 10 - Average Cross Entropy:= 0.004402578430175781
#
# Validation Accuracy: 0.8654
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8015
# Number of Epoch = 1 - Average Cross Entropy:= 0.009444163818359375
#
# Validation Accuracy: 0.7956
#
# Train Accuracy: 0.8366
# Number of Epoch = 2 - Average Cross Entropy:= 0.005889917602539063
#
# Validation Accuracy: 0.8261
#
# Train Accuracy: 0.8495
# Number of Epoch = 3 - Average Cross Entropy:= 0.00532918701171875
#
# Validation Accuracy: 0.8408
#
# Train Accuracy: 0.8580
# Number of Epoch = 4 - Average Cross Entropy:= 0.0050429568481445315
#
# Validation Accuracy: 0.8484
#
# Train Accuracy: 0.8634
# Number of Epoch = 5 - Average Cross Entropy:= 0.004844456787109375
#
# Validation Accuracy: 0.8549
#
# Train Accuracy: 0.8676
# Number of Epoch = 6 - Average Cross Entropy:= 0.004694716796875
#
# Validation Accuracy: 0.8588
#
# Train Accuracy: 0.8718
# Number of Epoch = 7 - Average Cross Entropy:= 0.004575713500976563
#
# Validation Accuracy: 0.8620
#
# Train Accuracy: 0.8756
# Number of Epoch = 8 - Average Cross Entropy:= 0.004472934875488281
#
# Validation Accuracy: 0.8640
#
# Train Accuracy: 0.8778
# Number of Epoch = 9 - Average Cross Entropy:= 0.004382598876953125
#
# Validation Accuracy: 0.8669
#
# Train Accuracy: 0.8809
# Number of Epoch = 10 - Average Cross Entropy:= 0.004302783203125
#
# Validation Accuracy: 0.8694
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8089
# Number of Epoch = 1 - Average Cross Entropy:= 0.009506088256835937
#
# Validation Accuracy: 0.8021
#
# Train Accuracy: 0.8373
# Number of Epoch = 2 - Average Cross Entropy:= 0.0059183197021484375
#
# Validation Accuracy: 0.8281
#
# Train Accuracy: 0.8500
# Number of Epoch = 3 - Average Cross Entropy:= 0.005400101318359375
#
# Validation Accuracy: 0.8395
#
# Train Accuracy: 0.8586
# Number of Epoch = 4 - Average Cross Entropy:= 0.005118839416503906
#
# Validation Accuracy: 0.8474
#
# Train Accuracy: 0.8639
# Number of Epoch = 5 - Average Cross Entropy:= 0.004919437866210938
#
# Validation Accuracy: 0.8520
#
# Train Accuracy: 0.8682
# Number of Epoch = 6 - Average Cross Entropy:= 0.0047646044921875
#
# Validation Accuracy: 0.8549
#
# Train Accuracy: 0.8724
# Number of Epoch = 7 - Average Cross Entropy:= 0.004638163146972656
#
# Validation Accuracy: 0.8593
#
# Train Accuracy: 0.8767
# Number of Epoch = 8 - Average Cross Entropy:= 0.0045326953125
#
# Validation Accuracy: 0.8640
#
# Train Accuracy: 0.8794
# Number of Epoch = 9 - Average Cross Entropy:= 0.004436565246582032
#
# Validation Accuracy: 0.8670
#
# Train Accuracy: 0.8819
# Number of Epoch = 10 - Average Cross Entropy:= 0.004355787048339844
#
# Validation Accuracy: 0.8685
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8061
# Number of Epoch = 1 - Average Cross Entropy:= 0.009818540649414063
#
# Validation Accuracy: 0.7990
#
# Train Accuracy: 0.8354
# Number of Epoch = 2 - Average Cross Entropy:= 0.005919119262695312
#
# Validation Accuracy: 0.8255
#
# Train Accuracy: 0.8473
# Number of Epoch = 3 - Average Cross Entropy:= 0.0053728643798828125
#
# Validation Accuracy: 0.8394
#
# Train Accuracy: 0.8542
# Number of Epoch = 4 - Average Cross Entropy:= 0.005091889038085938
#
# Validation Accuracy: 0.8469
#
# Train Accuracy: 0.8598
# Number of Epoch = 5 - Average Cross Entropy:= 0.004895957946777343
#
# Validation Accuracy: 0.8529
#
# Train Accuracy: 0.8652
# Number of Epoch = 6 - Average Cross Entropy:= 0.004747551574707031
#
# Validation Accuracy: 0.8568
#
# Train Accuracy: 0.8705
# Number of Epoch = 7 - Average Cross Entropy:= 0.004625566711425781
#
# Validation Accuracy: 0.8608
#
# Train Accuracy: 0.8738
# Number of Epoch = 8 - Average Cross Entropy:= 0.0045203070068359375
#
# Validation Accuracy: 0.8640
#
# Train Accuracy: 0.8769
# Number of Epoch = 9 - Average Cross Entropy:= 0.004431939086914062
#
# Validation Accuracy: 0.8657
#
# Train Accuracy: 0.8797
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043522079467773435
#
# Validation Accuracy: 0.8679
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8072
# Number of Epoch = 1 - Average Cross Entropy:= 0.009392955932617188
#
# Validation Accuracy: 0.7974
#
# Train Accuracy: 0.8373
# Number of Epoch = 2 - Average Cross Entropy:= 0.00586989990234375
#
# Validation Accuracy: 0.8258
#
# Train Accuracy: 0.8493
# Number of Epoch = 3 - Average Cross Entropy:= 0.005360669555664063
#
# Validation Accuracy: 0.8370
#
# Train Accuracy: 0.8573
# Number of Epoch = 4 - Average Cross Entropy:= 0.005082684631347656
#
# Validation Accuracy: 0.8446
#
# Train Accuracy: 0.8636
# Number of Epoch = 5 - Average Cross Entropy:= 0.004886386108398437
#
# Validation Accuracy: 0.8502
#
# Train Accuracy: 0.8680
# Number of Epoch = 6 - Average Cross Entropy:= 0.0047358935546875
#
# Validation Accuracy: 0.8543
#
# Train Accuracy: 0.8711
# Number of Epoch = 7 - Average Cross Entropy:= 0.004613323059082031
#
# Validation Accuracy: 0.8570
#
# Train Accuracy: 0.8742
# Number of Epoch = 8 - Average Cross Entropy:= 0.004508640441894531
#
# Validation Accuracy: 0.8605
#
# Train Accuracy: 0.8771
# Number of Epoch = 9 - Average Cross Entropy:= 0.004417800598144532
#
# Validation Accuracy: 0.8631
#
# Train Accuracy: 0.8796
# Number of Epoch = 10 - Average Cross Entropy:= 0.004336952209472656
#
# Validation Accuracy: 0.8639
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8050
# Number of Epoch = 1 - Average Cross Entropy:= 0.009247359008789063
#
# Validation Accuracy: 0.7987
#
# Train Accuracy: 0.8355
# Number of Epoch = 2 - Average Cross Entropy:= 0.005930894165039062
#
# Validation Accuracy: 0.8260
#
# Train Accuracy: 0.8489
# Number of Epoch = 3 - Average Cross Entropy:= 0.005381838989257813
#
# Validation Accuracy: 0.8391
#
# Train Accuracy: 0.8577
# Number of Epoch = 4 - Average Cross Entropy:= 0.005090680236816406
#
# Validation Accuracy: 0.8457
#
# Train Accuracy: 0.8636
# Number of Epoch = 5 - Average Cross Entropy:= 0.004893935546875
#
# Validation Accuracy: 0.8544
#
# Train Accuracy: 0.8681
# Number of Epoch = 6 - Average Cross Entropy:= 0.004743052368164063
#
# Validation Accuracy: 0.8581
#
# Train Accuracy: 0.8718
# Number of Epoch = 7 - Average Cross Entropy:= 0.004625083618164063
#
# Validation Accuracy: 0.8628
#
# Train Accuracy: 0.8759
# Number of Epoch = 8 - Average Cross Entropy:= 0.004525828247070312
#
# Validation Accuracy: 0.8649
#
# Train Accuracy: 0.8785
# Number of Epoch = 9 - Average Cross Entropy:= 0.004439371948242187
#
# Validation Accuracy: 0.8665
#
# Train Accuracy: 0.8814
# Number of Epoch = 10 - Average Cross Entropy:= 0.004363190002441406
#
# Validation Accuracy: 0.8680
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8100
# Number of Epoch = 1 - Average Cross Entropy:= 0.009156538696289062
#
# Validation Accuracy: 0.8047
#
# Train Accuracy: 0.8386
# Number of Epoch = 2 - Average Cross Entropy:= 0.005903956909179687
#
# Validation Accuracy: 0.8295
#
# Train Accuracy: 0.8521
# Number of Epoch = 3 - Average Cross Entropy:= 0.005400699462890625
#
# Validation Accuracy: 0.8408
#
# Train Accuracy: 0.8593
# Number of Epoch = 4 - Average Cross Entropy:= 0.005122132568359375
#
# Validation Accuracy: 0.8481
#
# Train Accuracy: 0.8648
# Number of Epoch = 5 - Average Cross Entropy:= 0.004933011169433594
#
# Validation Accuracy: 0.8543
#
# Train Accuracy: 0.8687
# Number of Epoch = 6 - Average Cross Entropy:= 0.004786469116210937
#
# Validation Accuracy: 0.8587
#
# Train Accuracy: 0.8719
# Number of Epoch = 7 - Average Cross Entropy:= 0.0046666390991210935
#
# Validation Accuracy: 0.8624
#
# Train Accuracy: 0.8753
# Number of Epoch = 8 - Average Cross Entropy:= 0.004561471557617188
#
# Validation Accuracy: 0.8634
#
# Train Accuracy: 0.8780
# Number of Epoch = 9 - Average Cross Entropy:= 0.0044702783203125
#
# Validation Accuracy: 0.8669
#
# Train Accuracy: 0.8802
# Number of Epoch = 10 - Average Cross Entropy:= 0.004389925842285156
#
# Validation Accuracy: 0.8695
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8017
# Number of Epoch = 1 - Average Cross Entropy:= 0.00953287109375
#
# Validation Accuracy: 0.7950
#
# Train Accuracy: 0.8341
# Number of Epoch = 2 - Average Cross Entropy:= 0.005951915283203125
#
# Validation Accuracy: 0.8254
#
# Train Accuracy: 0.8478
# Number of Epoch = 3 - Average Cross Entropy:= 0.005409892578125
#
# Validation Accuracy: 0.8398
#
# Train Accuracy: 0.8576
# Number of Epoch = 4 - Average Cross Entropy:= 0.005119172668457031
#
# Validation Accuracy: 0.8480
#
# Train Accuracy: 0.8641
# Number of Epoch = 5 - Average Cross Entropy:= 0.004918678588867188
#
# Validation Accuracy: 0.8524
#
# Train Accuracy: 0.8686
# Number of Epoch = 6 - Average Cross Entropy:= 0.004763326416015625
#
# Validation Accuracy: 0.8569
#
# Train Accuracy: 0.8723
# Number of Epoch = 7 - Average Cross Entropy:= 0.0046403466796875
#
# Validation Accuracy: 0.8594
#
# Train Accuracy: 0.8759
# Number of Epoch = 8 - Average Cross Entropy:= 0.004533682250976562
#
# Validation Accuracy: 0.8633
#
# Train Accuracy: 0.8787
# Number of Epoch = 9 - Average Cross Entropy:= 0.004442303466796875
#
# Validation Accuracy: 0.8637
#
# Train Accuracy: 0.8823
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043627838134765624
#
# Validation Accuracy: 0.8662
#
# Test Accuracy: 0.86
#
# Train Accuracy: 0.8065
# Number of Epoch = 1 - Average Cross Entropy:= 0.009511123657226563
#
# Validation Accuracy: 0.8023
#
# Train Accuracy: 0.8372
# Number of Epoch = 2 - Average Cross Entropy:= 0.005934315185546875
#
# Validation Accuracy: 0.8298
#
# Train Accuracy: 0.8495
# Number of Epoch = 3 - Average Cross Entropy:= 0.0053817822265625
#
# Validation Accuracy: 0.8429
#
# Train Accuracy: 0.8560
# Number of Epoch = 4 - Average Cross Entropy:= 0.005097123107910156
#
# Validation Accuracy: 0.8506
#
# Train Accuracy: 0.8619
# Number of Epoch = 5 - Average Cross Entropy:= 0.0049013330078125
#
# Validation Accuracy: 0.8562
#
# Train Accuracy: 0.8664
# Number of Epoch = 6 - Average Cross Entropy:= 0.0047496923828125
#
# Validation Accuracy: 0.8609
#
# Train Accuracy: 0.8697
# Number of Epoch = 7 - Average Cross Entropy:= 0.004629716186523437
#
# Validation Accuracy: 0.8634
#
# Train Accuracy: 0.8738
# Number of Epoch = 8 - Average Cross Entropy:= 0.004524414672851563
#
# Validation Accuracy: 0.8648
#
# Train Accuracy: 0.8765
# Number of Epoch = 9 - Average Cross Entropy:= 0.004432397155761719
#
# Validation Accuracy: 0.8671
#
# Train Accuracy: 0.8797
# Number of Epoch = 10 - Average Cross Entropy:= 0.0043517633056640624
#
# Validation Accuracy: 0.8695
#
# Test Accuracy: 0.86

# %%
totalTestAcc_avg=np.mean(totalTestAcc)
var=np.var(totalTestAcc)
print(f"the test Acc_avg of custom optimizer is {totalTestAcc_avg}, and the variance is {var}")
print(f"the running time for custom optimizer is: {38.29} mins")
# Out:
# the test Acc_avg of custom optimizer is 0.8597200512886047, and the variance is 2.4515709355910076e-06
# the running time for custom optimizer is: 38.29 mins

# %%
totalTestAcc_adam_avg=np.mean(totalTestAcc_adam)
var=np.var(totalTestAcc_adam)
print(f"the test Acc_avg of custom optimizer is {totalTestAcc_adam_avg}, and the variance is {var}")
print(f"the running time for custom optimizer is: {27.89} mins")
# Out:
# the test Acc_avg of custom optimizer is 0.8599900007247925, and the variance is 2.3229149519465864e-06
# the running time for custom optimizer is: 27.89 mins
